# %%
import sys
sys.path.append("/Users/nikita/Desktop/Test Assigment tabby")


from src.dataloader import DataLoader
from src.estimator import ModelEvaluator

import numpy as np
import lightgbm as lgb
import pickle
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
import shap
import optuna


import warnings

warnings.filterwarnings("ignore")

# %%
with open('/Users/nikita/Desktop/Test Assigment tabby/data/best_cols.pkl', 'rb') as f:
    best_features = pickle.load(f)

dl = DataLoader(path_to_data="/Users/nikita/Desktop/Test Assigment tabby/data/clear_dataset.csv",
                time_column='sample_date',
                threshold_cat_feature=5,
                drop_disbalance=None)

X_train, X_test, y_train, y_test = dl.run()

total_samples = len(y_train)
class_weight_0 = total_samples / (2 * np.bincount(y_train)[0])
class_weight_1 = total_samples / (2 * np.bincount(y_train)[1])

class_weights = {0: class_weight_0, 1: class_weight_1}

# %% [markdown]
# ### Interpret weights of Logistic Regression

# %%
model = LogisticRegression(class_weight=class_weights)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train[best_features])
X_test_scaled = scaler.transform(X_test[best_features])
evaluator = ModelEvaluator(model)
model = evaluator.run(X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Metrics:   train test
# ROC_AUC:   0.744 0.736
# Gini:      0.488 0.473
# F1_score:  0.294 0.277
# Log_loss:  11.048 10.935

# %%
feature_importance = model.coef_[0]
sorted_idx = np.argsort(np.abs(feature_importance))[::-1]

sorted_feature_names = X_train.columns[sorted_idx]
sorted_feature_importance = feature_importance[sorted_idx]

plt.figure(figsize=(20, 10))
plt.bar(range(len(sorted_feature_importance)), sorted_feature_importance, align="center")
plt.xticks(range(len(sorted_feature_importance)), sorted_feature_names, rotation=90)
plt.xlabel("Feature")
plt.ylabel("Feature Importance")
plt.title("Logistic Regression Feature Importance")
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Feature importance of lightGBM

# %%
params = {"num_leaves": 93,
          "learning_rate": 0.0567411581353529,
          "feature_fraction": 0.5093894964503696,
          "bagging_fraction": 0.9761155911592959,
          "bagging_freq": 3,
          "max_depth": 16,
          "min_child_samples": 18}
model = lgb.LGBMClassifier(verbose=-1, class_weight=class_weights, **params)
evaluator = ModelEvaluator(model)
model = evaluator.run(X_train[best_features], X_test[best_features], y_train, y_test)
# Out:
# Metrics:   train test
# ROC_AUC:   0.977 0.771
# Gini:      0.954 0.542
# F1_score:  0.645 0.343
# Log_loss:  3.786 6.275

# %%
lgb.plot_importance(model, max_num_features=25)  # Set max_num_features as needed
plt.show()

# %% [markdown]
# ### SHAP

# %%
explainer = shap.Explainer(model)
shap_values = explainer.shap_values(X_test[best_features]) 

shap.summary_plot(shap_values, X_test[best_features], plot_type="bar")
plt.show()

# %%
shap.summary_plot(shap_values[0], X_test[best_features])

# %% [markdown]
# ### ALE

# %%
# !pip install git+https://github.com/MaximeJumelle/ALEPython.git@dev#egg=alepython
from alepython import ale_plot

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg'
# Out:
# Collecting alepython
#   Cloning https://github.com/MaximeJumelle/ALEPython.git (to revision dev) to /private/var/folders/cb/n7klvybs09g2ycl4j5z4b5800000gn/T/pip-install-6bv316sr/alepython_edee3d7e19c548f8a72318a48aa4c653
#   Running command git clone --filter=blob:none --quiet https://github.com/MaximeJumelle/ALEPython.git /private/var/folders/cb/n7klvybs09g2ycl4j5z4b5800000gn/T/pip-install-6bv316sr/alepython_edee3d7e19c548f8a72318a48aa4c653
#   Resolved https://github.com/MaximeJumelle/ALEPython.git to commit 286350ab674980a32270db2a0b5ccca1380312a7
#   Preparing metadata (setup.py) ... done
# Collecting loguru>=0.4.1 (from alepython)
#   Obtaining dependency information for loguru>=0.4.1 from https://files.pythonhosted.org/packages/03/0a/4f6fed21aa246c6b49b561ca55facacc2a44b87d65b8b92362a8e99ba202/loguru-0.7.2-py3-none-any.whl.metadata
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: matplotlib>=2.2.3 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from alepython) (3.8.0)
# Requirement already satisfied: numpy>=1.15.4 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from alepython) (1.25.2)
# Requirement already satisfied: pandas>=0.22.0 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from alepython) (2.1.1)
# Requirement already satisfied: scipy>=1.1.0 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from alepython) (1.11.3)
# Requirement already satisfied: seaborn>=0.9.0 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from alepython) (0.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from matplotlib>=2.2.3->alepython) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from matplotlib>=2.2.3->alepython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from matplotlib>=2.2.3->alepython) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from matplotlib>=2.2.3->alepython) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from matplotlib>=2.2.3->alepython) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from matplotlib>=2.2.3->alepython) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from matplotlib>=2.2.3->alepython) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from matplotlib>=2.2.3->alepython) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from pandas>=0.22.0->alepython) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from pandas>=0.22.0->alepython) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/nikita/Desktop/Test Assigment tabby/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->alepython) (1.16.0)
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 158.8 kB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: alepython
#   Building wheel for alepython (setup.py) ... done
#   Created wheel for alepython: filename=alepython-0.1.dev17+g286350a-py3-none-any.whl size=15140 sha256=22b38affd20c5555540db7104be7ac2bbb30d0e96af3e76628daf8cc2df6382c
#   Stored in directory: /private/var/folders/cb/n7klvybs09g2ycl4j5z4b5800000gn/T/pip-ephem-wheel-cache-3g0sri2m/wheels/ac/d2/e4/cd88ce55641d5422cdba165bd6f18c6fb6c0035385dc2bcce2
# Successfully built alepython
# Installing collected packages: loguru, alepython
# Successfully installed alepython-0.1.dev17+g286350a loguru-0.7.2

# %%
ale_plot(model=model, 
         train_set=X_train[best_features].sample(5000), 
         features='DayofYear', 
         bins=12, 
         monte_carlo=True, 
         monte_carlo_rep=50,
         monte_carlo_ratio=0.6);
# Out:
# <Axes: title={'center': "First-order ALE of feature 'DayofYear'\nBins : 12 - Monte-Carlo : 50"}, xlabel="Feature 'DayofYear'">

# %%
ale_plot(model=model, 
         train_set=X_train[best_features].sample(5000), 
         features='feature_67', 
         bins=12, 
         monte_carlo=True, 
         monte_carlo_rep=50,
         monte_carlo_ratio=0.6);

# %%
ale_plot(model=model, 
         train_set=X_train[best_features].sample(5000), 
         features='feature_134', 
         bins=12, 
         monte_carlo=True, 
         monte_carlo_rep=50,
         monte_carlo_ratio=0.6);
